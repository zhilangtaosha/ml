# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from scipy.stats import norm
from scipy import stats

import xgboost as xgb
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv("../../../mltestdata/03_predict_hourly_wage/Income_training.csv")
test = pd.read_csv("../../../mltestdata/03_predict_hourly_wage/Income_testing.csv")

# %% [markdown]
# # Preprocessiong
# * * * *

# %% [markdown]
# * * *

# %%
train_target = train.compositeHourlyWages.values

test_ID = test['ID']
test.drop("ID", axis = 1, inplace = True)

train.drop(['compositeHourlyWages'], axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(train,train_target,test_size=0.2,random_state=0)

# %% [markdown]
# # Modeling
# * * * * *

# %% [markdown]
# ## XGBoost

# %% [markdown]
# ### 1. Validation with local train

# %%
# xgboostモデルの作成
#ind_params = {'objective': 'reg:linear'}

#reg = xgb.XGBRegressor(**ind_params)
reg = xgb.XGBRegressor()
reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
y_train_predict = reg.predict(X_train)
y_pred = reg.predict(X_test)

# %%
# The error metric: RMSE
from sklearn.metrics import mean_squared_error, r2_score, make_scorer

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

print("RMSE from local train: ", rmse(y_test, y_pred))
print("MSE from local train: ", mean_squared_error(y_test, y_pred))
print("R2 from local train: ", r2_score(y_test, y_pred))
# Out:
# RMSE from local train:  6.02475299555
# MSE from local train:  36.2976486573
# R2 from local train:  0.395235324935

# %% [markdown]
# ### 2. Validation with GridSearch

# %%
from sklearn.model_selection import GridSearchCV

# %%
# XGBoost params
xgb_params = {
    'objective' : ['reg:gamma','reg:linear'],
    'learning_rate' : [0.05,0.1],
    'n_estimators' : [50,100,200],
    'max_depth' : [2,4,6],
    'subsample' : [0.8,0.85,0.9,0.95],
    'colsample_bytree' : [0.5,1.0],
    'min_child_weight' : [5,10,15]
}

# %%
#scoring_func = make_scorer(mean_squared_error)

#grid = GridSearchCV(reg,xgb_params,scoring=scoring_func,cv=5,n_jobs=-1)
grid = GridSearchCV(reg,xgb_params,scoring='neg_mean_squared_error',cv=5,n_jobs=-1)

grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'objective': ['reg:gamma', 'reg:linear'], 'learning_rate': [0.05, 0.1], 'n_estimators': [50, 100, 200], 'max_depth': [2, 4, 6], 'subsample': [0.8, 0.85, 0.9, 0.95], 'colsample_bytree': [0.5, 1.0], 'min_child_weight': [5, 10, 15]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='neg_mean_squared_error', verbose=0)

# %%
# Best Params and Score
print("Best params: ", grid.best_params_)
print("Best Estimator: ", grid.best_estimator_)

print("MSE: ", grid.best_score_)

# best_score_ : Mean cross-validated score of the best_estimator
# Out:
# Best params:  {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.8}
# Best Estimator:  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=2, min_child_weight=15, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:gamma', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=0.8)
# MSE:  -38.8108460369

# %%
# The result of combination
index = 1
for params, mean_score, scores in grid.grid_scores_:
    print("%d) %0.3f (+/-%0.03f) " % (index, mean_score, scores.std() / 2))
    print("Params: %r" % params)
    print("_"*30)
    index = index + 1
# Out:
# /Users/suzukiry/lab/March/lib/python3.6/site-packages/sklearn/model_selection/_search.py:747: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# 1) -182.547 (+/-4.804)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.8}
# ______________________________
# 2) -182.552 (+/-4.804)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.85}
# ______________________________
# 3) -182.551 (+/-4.804)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 4) -182.560 (+/-4.805)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 5) -45.105 (+/-1.839)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 6) -45.117 (+/-1.834)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
# 7) -45.140 (+/-1.843)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.9}
# ______________________________
# 8) -45.170 (+/-1.842)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.95}
# ______________________________
# 9) -55.318 (+/-2.426)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.8}
# ______________________________
# 10) -55.336 (+/-2.432)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.85}
# ______________________________
# 11) -55.326 (+/-2.430)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 12) -55.369 (+/-2.442)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 13) -40.924 (+/-1.379)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 14) -40.971 (+/-1.386)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
# 15) -40.966 (+/-1.374)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.9}
# ______________________________
# 16) -40.976 (+/-1.375)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.95}
# ______________________________
# 17) -40.010 (+/-1.395)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.8}
# ______________________________
# 18) -40.030 (+/-1.384)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.85}
# ______________________________
# 19) -40.027 (+/-1.372)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 20) -40.032 (+/-1.374)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 21) -40.313 (+/-1.238)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 22) -40.344 (+/-1.250)
# Params: {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
#

# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 804) -41.282 (+/-1.241)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 805) -43.145 (+/-1.216)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 806) -43.035 (+/-1.197)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
# 807) -42.932 (+/-1.139)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.9}
# ______________________________
# 808) -42.986 (+/-1.093)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.95}
# ______________________________
# 809) -44.740 (+/-1.330)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.8}
# ______________________________
# 810) -44.719 (+/-1.281)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.85}
# ______________________________
# 811) -44.812 (+/-1.263)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 812) -44.684 (+/-1.196)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 813) -46.094 (+/-1.167)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 814) -45.783 (+/-1.174)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
# 815) -45.882 (+/-1.163)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.9}
# ______________________________
# 816) -45.779 (+/-1.139)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.95}
# ______________________________
# 817) -48.838 (+/-2.014)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.8}
# ______________________________
# 818) -48.916 (+/-2.058)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.85}
# ______________________________
# 819) -48.937 (+/-1.991)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 820) -48.760 (+/-2.003)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 821) -40.537 (+/-1.193)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 822) -40.445 (+/-1.246)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
# 823) -40.478 (+/-1.175)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.9}
# ______________________________
# 824) -40.456 (+/-1.355)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.95}
# ______________________________
# 825) -40.953 (+/-1.251)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.8}
# ______________________________
# 826) -40.759 (+/-1.211)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.85}
# ______________________________
# 827) -40.841 (+/-1.138)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 828) -40.862 (+/-1.160)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 829) -42.120 (+/-1.119)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 830) -41.972 (+/-1.196)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
# 831) -41.930 (+/-1.115)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.9}
# ______________________________
# 832) -41.903 (+/-1.174)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.95}
# ______________________________
# 833) -43.690 (+/-1.276)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.8}
# ______________________________
# 834) -43.107 (+/-1.240)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.85}
# ______________________________
# 835) -43.147 (+/-1.135)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 836) -43.250 (+/-1.193)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 837) -44.231 (+/-1.120)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 838) -44.134 (+/-1.153)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
# 839) -44.046 (+/-1.045)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.9}
# ______________________________
# 840) -44.079 (+/-1.172)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 10, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.95}
# ______________________________
# 841) -48.763 (+/-2.042)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.8}
# ______________________________
# 842) -48.800 (+/-2.021)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.85}
# ______________________________
# 843) -48.743 (+/-1.992)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 844) -48.663 (+/-2.018)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 50, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 845) -40.243 (+/-1.149)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 846) -40.226 (+/-1.200)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
# 847) -40.194 (+/-1.208)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.9}
# ______________________________
# 848) -40.242 (+/-1.303)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 50, 'objective': 'reg:linear', 'subsample': 0.95}
# ______________________________
# 849) -40.582 (+/-1.248)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.8}
# ______________________________
# 850) -40.440 (+/-1.218)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.85}
# ______________________________
# 851) -40.509 (+/-1.199)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 852) -40.531 (+/-1.193)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 853) -41.457 (+/-1.095)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 854) -41.565 (+/-1.224)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
# 855) -41.356 (+/-1.208)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.9}
# ______________________________
# 856) -41.491 (+/-1.123)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 100, 'objective': 'reg:linear', 'subsample': 0.95}
# ______________________________
# 857) -42.485 (+/-1.300)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.8}
# ______________________________
# 858) -42.511 (+/-1.155)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.85}
# ______________________________
# 859) -42.324 (+/-1.219)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.9}
# ______________________________
# 860) -42.517 (+/-1.180)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 200, 'objective': 'reg:gamma', 'subsample': 0.95}
# ______________________________
# 861) -43.168 (+/-1.163)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.8}
# ______________________________
# 862) -43.366 (+/-1.102)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.85}
# ______________________________
# 863) -43.052 (+/-1.128)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.9}
# ______________________________
# 864) -43.258 (+/-1.089)
# Params: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 15, 'n_estimators': 200, 'objective': 'reg:linear', 'subsample': 0.95}
# ______________________________

# %%
# 改めて最適パラメータで学習
gdm = xgb.XGBRegressor(**grid.best_params_) # 6.01679534923
#gdm = xgb.XGBRegressor(**xgb_params) # 6.0907929398
gdm.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=2, min_child_weight=15, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:gamma', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=0.8)

# %%
y_pred_gs = gdm.predict(X_test)

# %%
# The error metric: RMSE
print("RMSE from local train: ", rmse(y_test, y_pred_gs))
print("MSE from local train: ", mean_squared_error(y_test, y_pred_gs))
print("R2 from local train: ", r2_score(y_test, y_pred_gs))
# Out:
# RMSE from local train:  5.99341470614
# MSE from local train:  35.9210198398
# R2 from local train:  0.401510436764

# %%
predictions_gdm = gdm.predict(test)

# %% [markdown]
# __Findings__
# - RMSEがやや下がっている。
# - R2がやや増えている。過学習までには至っていないと判断。

# %% [markdown]
# # Submission

# %%
sub = pd.DataFrame()
sub['ID'] = test_ID
sub['compositeHourlyWages'] = predictions_gdm
sub.to_csv('rs_hourly_submission_27Dec17.csv',index=False)

# %% [markdown]
# * * * *

# %% [markdown]
# Public LB: Your submission scored 6.30636
