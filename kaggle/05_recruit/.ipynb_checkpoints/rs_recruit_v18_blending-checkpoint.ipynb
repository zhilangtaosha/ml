# %% [markdown]
# # Feature Engineering

# %%
from sklearn.model_selection import KFold, GridSearchCV, train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error,r2_score
import time

import lightgbm as lgb
from lightgbm import LGBMRegressor
from bayes_opt import BayesianOptimization

import warnings
warnings.filterwarnings("ignore")

# %%
"""
Contributions from:
DSEverything - Mean Mix - Math, Geo, Harmonic (LB 0.493) 
https://www.kaggle.com/dongxu027/mean-mix-math-geo-harmonic-lb-0-493
JdPaletto - Surprised Yet? - Part2 - (LB: 0.503)
https://www.kaggle.com/jdpaletto/surprised-yet-part2-lb-0-503
hklee - weighted mean comparisons, LB 0.497, 1ST
https://www.kaggle.com/zeemeen/weighted-mean-comparisons-lb-0-497-1st

Also all comments for changes, encouragement, and forked scripts rock

Keep the Surprise Going
"""

import glob, re
import numpy as np
import pandas as pd
from sklearn import *
from datetime import datetime

data = {
    'tra': pd.read_csv('../../../mltestdata/05_recruit/air_visit_data.csv'),
    'as': pd.read_csv('../../../mltestdata/05_recruit/air_store_info.csv'),
    'hs': pd.read_csv('../../../mltestdata/05_recruit/hpg_store_info.csv'),
    'ar': pd.read_csv('../../../mltestdata/05_recruit/air_reserve.csv'),
    'hr': pd.read_csv('../../../mltestdata/05_recruit/hpg_reserve.csv'),
    'id': pd.read_csv('../../../mltestdata/05_recruit/store_id_relation.csv'),
    'tes': pd.read_csv('../../../mltestdata/05_recruit/sample_submission.csv'),
    'hol': pd.read_csv('../../../mltestdata/05_recruit/date_info.csv').rename(columns={'calendar_date':'visit_date'})
    }

data['hr'] = pd.merge(data['hr'], data['id'], how='inner', on=['hpg_store_id'])

for df in ['ar','hr']:
    data[df]['visit_datetime'] = pd.to_datetime(data[df]['visit_datetime'])
    data[df]['visit_datetime'] = data[df]['visit_datetime'].dt.date
    data[df]['reserve_datetime'] = pd.to_datetime(data[df]['reserve_datetime'])
    data[df]['reserve_datetime'] = data[df]['reserve_datetime'].dt.date
    data[df]['reserve_datetime_diff'] = data[df].apply(lambda r: (r['visit_datetime'] - r['reserve_datetime']).days, axis=1)
    tmp1 = data[df].groupby(['air_store_id','visit_datetime'], as_index=False)[['reserve_datetime_diff', 'reserve_visitors']].sum().rename(columns={'visit_datetime':'visit_date', 'reserve_datetime_diff': 'rs1', 'reserve_visitors':'rv1'})
    tmp2 = data[df].groupby(['air_store_id','visit_datetime'], as_index=False)[['reserve_datetime_diff', 'reserve_visitors']].mean().rename(columns={'visit_datetime':'visit_date', 'reserve_datetime_diff': 'rs2', 'reserve_visitors':'rv2'})
    data[df] = pd.merge(tmp1, tmp2, how='inner', on=['air_store_id','visit_date'])

data['tra']['visit_date'] = pd.to_datetime(data['tra']['visit_date'])
data['tra']['dow'] = data['tra']['visit_date'].dt.dayofweek
data['tra']['year'] = data['tra']['visit_date'].dt.year
data['tra']['month'] = data['tra']['visit_date'].dt.month
data['tra']['visit_date'] = data['tra']['visit_date'].dt.date

data['tes']['visit_date'] = data['tes']['id'].map(lambda x: str(x).split('_')[2])
data['tes']['air_store_id'] = data['tes']['id'].map(lambda x: '_'.join(x.split('_')[:2]))
data['tes']['visit_date'] = pd.to_datetime(data['tes']['visit_date'])
data['tes']['dow'] = data['tes']['visit_date'].dt.dayofweek
data['tes']['year'] = data['tes']['visit_date'].dt.year
data['tes']['month'] = data['tes']['visit_date'].dt.month
data['tes']['visit_date'] = data['tes']['visit_date'].dt.date

unique_stores = data['tes']['air_store_id'].unique()
stores = pd.concat([pd.DataFrame({'air_store_id': unique_stores, 'dow': [i]*len(unique_stores)}) for i in range(7)], axis=0, ignore_index=True).reset_index(drop=True)

#sure it can be compressed...
tmp = data['tra'].groupby(['air_store_id','dow'], as_index=False)['visitors'].min().rename(columns={'visitors':'min_visitors'})
stores = pd.merge(stores, tmp, how='left', on=['air_store_id','dow']) 
tmp = data['tra'].groupby(['air_store_id','dow'], as_index=False)['visitors'].mean().rename(columns={'visitors':'mean_visitors'})
stores = pd.merge(stores, tmp, how='left', on=['air_store_id','dow'])
tmp = data['tra'].groupby(['air_store_id','dow'], as_index=False)['visitors'].median().rename(columns={'visitors':'median_visitors'})
stores = pd.merge(stores, tmp, how='left', on=['air_store_id','dow'])
tmp = data['tra'].groupby(['air_store_id','dow'], as_index=False)['visitors'].max().rename(columns={'visitors':'max_visitors'})
stores = pd.merge(stores, tmp, how='left', on=['air_store_id','dow'])
tmp = data['tra'].groupby(['air_store_id','dow'], as_index=False)['visitors'].count().rename(columns={'visitors':'count_observations'})
stores = pd.merge(stores, tmp, how='left', on=['air_store_id','dow']) 

stores = pd.merge(stores, data['as'], how='left', on=['air_store_id']) 
# NEW FEATURES FROM Georgii Vyshnia
stores['air_genre_name'] = stores['air_genre_name'].map(lambda x: str(str(x).replace('/',' ')))
stores['air_area_name'] = stores['air_area_name'].map(lambda x: str(str(x).replace('-',' ')))
lbl = preprocessing.LabelEncoder()
for i in range(10):
    stores['air_genre_name'+str(i)] = lbl.fit_transform(stores['air_genre_name'].map(lambda x: str(str(x).split(' ')[i]) if len(str(x).split(' '))>i else ''))
    stores['air_area_name'+str(i)] = lbl.fit_transform(stores['air_area_name'].map(lambda x: str(str(x).split(' ')[i]) if len(str(x).split(' '))>i else ''))
stores['air_genre_name'] = lbl.fit_transform(stores['air_genre_name'])
stores['air_area_name'] = lbl.fit_transform(stores['air_area_name'])

data['hol']['visit_date'] = pd.to_datetime(data['hol']['visit_date'])
data['hol']['day_of_week'] = lbl.fit_transform(data['hol']['day_of_week'])
data['hol']['visit_date'] = data['hol']['visit_date'].dt.date
train = pd.merge(data['tra'], data['hol'], how='left', on=['visit_date']) 
test = pd.merge(data['tes'], data['hol'], how='left', on=['visit_date']) 

train = pd.merge(train, stores, how='left', on=['air_store_id','dow']) 
test = pd.merge(test, stores, how='left', on=['air_store_id','dow'])

for df in ['ar','hr']:
    train = pd.merge(train, data[df], how='left', on=['air_store_id','visit_date']) 
    test = pd.merge(test, data[df], how='left', on=['air_store_id','visit_date'])

train['id'] = train.apply(lambda r: '_'.join([str(r['air_store_id']), str(r['visit_date'])]), axis=1)

train['total_reserv_sum'] = train['rv1_x'] + train['rv1_y']
train['total_reserv_mean'] = (train['rv2_x'] + train['rv2_y']) / 2
train['total_reserv_dt_diff_mean'] = (train['rs2_x'] + train['rs2_y']) / 2

test['total_reserv_sum'] = test['rv1_x'] + test['rv1_y']
test['total_reserv_mean'] = (test['rv2_x'] + test['rv2_y']) / 2
test['total_reserv_dt_diff_mean'] = (test['rs2_x'] + test['rs2_y']) / 2

# NEW FEATURES FROM JMBULL
train['date_int'] = train['visit_date'].apply(lambda x: x.strftime('%Y%m%d')).astype(int)
test['date_int'] = test['visit_date'].apply(lambda x: x.strftime('%Y%m%d')).astype(int)
train['var_max_lat'] = train['latitude'].max() - train['latitude']
train['var_max_long'] = train['longitude'].max() - train['longitude']
test['var_max_lat'] = test['latitude'].max() - test['latitude']
test['var_max_long'] = test['longitude'].max() - test['longitude']

# NEW FEATURES FROM Georgii Vyshnia
train['lon_plus_lat'] = train['longitude'] + train['latitude'] 
test['lon_plus_lat'] = test['longitude'] + test['latitude']

lbl = preprocessing.LabelEncoder()
train['air_store_id2'] = lbl.fit_transform(train['air_store_id'])
test['air_store_id2'] = lbl.transform(test['air_store_id'])

col = [c for c in train if c not in ['id', 'air_store_id', 'visit_date','visitors']]
train = train.fillna(-1)
test = test.fillna(-1)

# %% [markdown]
# # EDA

# %%
# %matplotlib inline
train_true = pd.DataFrame()
train_true["true_visitors"] = train.visitors
train_xgb = pd.read_csv('./lv1_xgb_train_pred.csv', header=0, names=['xgb_visitors'])
train_knr = pd.read_csv('./lv1_knr_train_pred.csv', header=0, names=['knr_visitors'])

sub_total = pd.concat([train_true,train_xgb,train_knr], axis=1)

# %%
sub_total[0:300].plot( y=['true_visitors','xgb_visitors','knr_visitors'], figsize=(20,3), alpha=0.7)
#sub_total[301:600].plot( y=['true_visitors','xgb_visitors','knr_visitors'], figsize=(20,3), alpha=0.7)
#sub_total[601:900].plot( y=['true_visitors','xgb_visitors','knr_visitors'], figsize=(20,3), alpha=0.7)
sub_total[901:1200].plot( y=['true_visitors','xgb_visitors','knr_visitors'], figsize=(20,3), alpha=0.7)
sub_total[1201:1500].plot( y=['true_visitors','xgb_visitors','knr_visitors'], figsize=(20,3), alpha=0.7)

# %%
n = 1050
print("gn: "+str(train[n:n+1].air_genre_name))
print("an: "+str(train[n:n+1].air_area_name))
# Out:
# gn: 1050    4.0
# Name: air_genre_name, dtype: float64
# an: 1050    64.0
# Name: air_area_name, dtype: float64

# %%
n = 1450
print("gn: "+str(train[n:n+1].air_genre_name))
print("an: "+str(train[n:n+1].air_area_name))
# Out:
# gn: 1450    7.0
# Name: air_genre_name, dtype: float64
# an: 1450    58.0
# Name: air_area_name, dtype: float64

# %% [markdown]
# # Blending

# %% [markdown]
# ### 28-Jan-2018 v2

# %%
import pandas as pd
sub_xgb = pd.read_csv('./submission_rs_recruit_v14_xgb_linear_feature_engineering_shinji_02.csv', header=0, names=('id','xgb_visitors'))
sub_lgb = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_shinji_02.csv', header=0, names=('id','lgb_visitors'))
sub_knr = pd.read_csv('./submission_rs_recruit_v16_knr_feature_engineering_shinji_02.csv', header=0, names=('id','knr_visitors'))
sub_aml = pd.read_csv('./submission_automl_test.csv', header=0, names=('id','aml_visitors'))
sub_ker = pd.read_csv('./ker_Andy_Harless_keras.csv', header=0, names=('id','ker_visitors'))

sub_479 = pd.read_csv('../../../mltestdata/05_recruit/submission_automl.csv', header=0, names=('id','479_visitors'))

sub_total = pd.concat([sub_xgb,sub_lgb,sub_knr,sub_sak,sub_aml,sub_ker,sub_479], axis=1)

sub_blending = pd.DataFrame()
sub_blending['id'] = sub_xgb['id']

# %%
rate_xgb = 0.2
rate_lgb = 0.2

rate_knr = 0.2
rate_aml = 0.2
rate_ker = 0.2

sub_xgb = pd.read_csv('./submission_rs_recruit_v14_xgb_linear_feature_engineering_shinji_02.csv')
sub_lgb = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_shinji_02.csv')
sub_knr = pd.read_csv('./submission_rs_recruit_v16_knr_feature_engineering_shinji_02.csv')
sub_aml = pd.read_csv('./submission_automl_test.csv')
sub_ker = pd.read_csv('./ker_Andy_Harless_keras.csv')

# %%
sub_blending['visitors'] = rate_xgb*sub_xgb['visitors']\
+rate_lgb*sub_lgb['visitors']\
+rate_knr*sub_knr['visitors']\
+rate_aml*sub_aml['visitors']\
+rate_ker*sub_ker['visitors']\

sub_blending.to_csv('submission_rs_recruit_v18_blending_09.csv', index=False)
# xgb
# lgm
# knr
# aml
# ker
# blending xgb:2,lgb:2,knr:2,aml:2,ker:2
# LB 0.479

# %% [markdown]
# ### 28-Jan-2018

# %%
import pandas as pd
sub_xgb = pd.read_csv('./submission_rs_recruit_v14_xgb_linear_feature_engineering_shinji_02.csv', header=0, names=('id','xgb_visitors'))
sub_lgb = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_shinji_02.csv', header=0, names=('id','lgb_visitors'))
sub_knr = pd.read_csv('./submission_rs_recruit_v16_knr_feature_engineering_shinji_02.csv', header=0, names=('id','knr_visitors'))
sub_sak = pd.read_csv('./submission_rs_recruit_v20_sakata_02.csv', header=0, names=('id','sak_visitors'))
sub_aml = pd.read_csv('./submission_automl_test.csv', header=0, names=('id','aml_visitors'))
sub_ker = pd.read_csv('./ker_Andy_Harless_keras.csv', header=0, names=('id','ker_visitors'))

sub_479 = pd.read_csv('../../../mltestdata/05_recruit/submission_automl.csv', header=0, names=('id','479_visitors'))

sub_total = pd.concat([sub_xgb,sub_lgb,sub_knr,sub_sak,sub_aml,sub_ker,sub_479], axis=1)

sub_blending = pd.DataFrame()
sub_blending['id'] = sub_xgb['id']

# %%
rate_xgb = 0.2
rate_lgb = 0.2
rate_sak = 0.05

rate_knr = 0.15
rate_aml = 0.2
rate_ker = 0.2

sub_xgb = pd.read_csv('./submission_rs_recruit_v14_xgb_linear_feature_engineering_shinji_02.csv')
sub_lgb = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_shinji_02.csv')
sub_knr = pd.read_csv('./submission_rs_recruit_v16_knr_feature_engineering_shinji_02.csv')
sub_sak = pd.read_csv('./submission_rs_recruit_v20_sakata_02.csv')
sub_aml = pd.read_csv('./submission_automl_test.csv')
sub_ker = pd.read_csv('./ker_Andy_Harless_keras.csv')

# %%
sub_blending['visitors'] = rate_xgb*sub_xgb['visitors']\
+rate_lgb*sub_lgb['visitors']\
+rate_knr*sub_knr['visitors']\
+rate_sak*sub_sak['visitors']\
+rate_aml*sub_aml['visitors']\
+rate_ker*sub_ker['visitors']\

sub_blending.to_csv('submission_rs_recruit_v18_blending_08.csv', index=False)
# xgb
# lgm
# knr
# sakata method
# aml
# ker
# blending xgb:2,lgb:2,sakata method:0.5,knr:1.5,aml:2,ker:2
# LB 0.478

# %% [markdown]
# ### 27-Jan-2018 v2

# %%
import pandas as pd
sub_xgb = pd.read_csv('./submission_rs_recruit_v14_xgb_linear_feature_engineering_shinji_02.csv', header=0, names=('id','xgb_visitors'))
sub_lgb = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_shinji_02.csv', header=0, names=('id','lgb_visitors'))
sub_knr = pd.read_csv('./submission_rs_recruit_v16_knr_feature_engineering_shinji_02.csv', header=0, names=('id','knr_visitors'))
sub_sak = pd.read_csv('./submission_rs_recruit_v20_sakata_02.csv', header=0, names=('id','sak_visitors'))
sub_aml = pd.read_csv('./submission_automl_test.csv', header=0, names=('id','aml_visitors'))
sub_ker = pd.read_csv('./ker_Andy_Harless_keras.csv', header=0, names=('id','ker_visitors'))

sub_479 = pd.read_csv('../../../mltestdata/05_recruit/submission_automl.csv', header=0, names=('id','479_visitors'))

sub_total = pd.concat([sub_xgb,sub_lgb,sub_knr,sub_sak,sub_aml,sub_ker,sub_479], axis=1)

sub_blending = pd.DataFrame()
sub_blending['id'] = sub_xgb['id']

# %%
# %matplotlib inline

# %% [markdown]
# *genre*
# - 6:Italian
# - 2:cafe
# - 4:Dining bar
#
# *area name*
# - 44: 'Tōkyō to Chiyoda ku Kudanminami'
# - 102: 'Ōsaka fu Ōsaka shi Ōhiraki'
# - 31: 'Hyōgo ken Takarazuka shi Tōyōchō'
# - 68: 'Tōkyō to Setagaya ku Okusawa'
# - 30: 'Hyōgo ken Nishinomiya shi Rokutanjichō'

# %%
n = 710
print("gn: "+str(test[n:n+1].air_genre_name))
print("an: "+str(test[n:n+1].air_area_name))
# Out:
# gn: 710    4
# Name: air_genre_name, dtype: int64
# an: 710    58
# Name: air_area_name, dtype: int64

# %%
sub_total[0:300].plot( y=['lgb_visitors','ker_visitors','479_visitors'], figsize=(20,3), alpha=0.7)
sub_total[301:600].plot( y=['lgb_visitors','ker_visitors','479_visitors'], figsize=(20,3), alpha=0.7)
sub_total[601:900].plot( y=['lgb_visitors','ker_visitors','479_visitors'], figsize=(20,3), alpha=0.7)

# %%
sub_total[0:300].plot( y=['xgb_visitors','lgb_visitors','knr_visitors','sak_visitors','aml_visitors','ker_visitors'], figsize=(20,3), alpha=0.7)
sub_total[301:600].plot( y=['xgb_visitors','lgb_visitors','knr_visitors','sak_visitors','aml_visitors','ker_visitors'], figsize=(20,3), alpha=0.7)

# %%
rate_xgb = 0.2
rate_lgb = 0.2
rate_sak = 0.1

rate_knr = 0.1
rate_aml = 0.2
rate_ker = 0.2

sub_xgb = pd.read_csv('./submission_rs_recruit_v14_xgb_linear_feature_engineering_shinji_02.csv')
sub_lgb = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_shinji_02.csv')
sub_knr = pd.read_csv('./submission_rs_recruit_v16_knr_feature_engineering_shinji_02.csv')
sub_sak = pd.read_csv('./submission_rs_recruit_v20_sakata_02.csv')
sub_aml = pd.read_csv('./submission_automl_test.csv')
sub_ker = pd.read_csv('./ker_Andy_Harless_keras.csv')

# %%
sub_blending['visitors'] = rate_xgb*sub_xgb['visitors']\
+rate_lgb*sub_lgb['visitors']\
+rate_knr*sub_knr['visitors']\
+rate_sak*sub_sak['visitors']\
+rate_aml*sub_aml['visitors']\
+rate_ker*sub_ker['visitors']\

sub_blending.to_csv('submission_rs_recruit_v18_blending_07.csv', index=False)
# xgb
# lgm
# knr
# sakata method
# aml
# ker
# blending xgb:2,lgb:2,knr:1,sakata method:1,aml:2,ker:2
# LB 0.478

# %% [markdown]
# ### 27-Jan-2018 v1

# %%
import pandas as pd
sub_xgb = pd.read_csv('./submission_rs_recruit_v14_xgb_linear_feature_engineering_shinji_02.csv', header=0, names=('id','xgb_visitors'))
sub_lgb = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_shinji_02.csv', header=0, names=('id','lgb_visitors'))
sub_knr = pd.read_csv('./submission_rs_recruit_v16_knr_feature_engineering_shinji_02.csv', header=0, names=('id','knr_visitors'))
sub_sak = pd.read_csv('./submission_rs_recruit_v20_sakata_02.csv', header=0, names=('id','sak_visitors'))
sub_aml = pd.read_csv('./submission_automl_test.csv', header=0, names=('id','aml_visitors'))

sub_total = pd.concat([sub_xgb,sub_lgb,sub_knr,sub_sak,sub_aml], axis=1)

sub_blending = pd.DataFrame()
sub_blending['id'] = sub_xgb['id']

# %%
# %matplotlib inline

# %%
sub_total[0:300].plot( y=['xgb_visitors','lgb_visitors','knr_visitors','sak_visitors','aml_visitors'], figsize=(20,8), alpha=0.9)

# %%
sub_total[301:600].plot( y=['xgb_visitors','lgb_visitors','knr_visitors','sak_visitors','aml_visitors'], figsize=(20,8), alpha=0.9)

# %%
rate_xgb = 0.2
rate_lgb = 0.2
rate_sak = 0.2

rate_knr = 0.2
rate_aml = 0.2

# %%
sub_blending['visitors'] = rate_xgb*sub_xgb['visitors']\
+rate_lgb*sub_lgb['visitors']\
+rate_knr*sub_knr['visitors']\
+rate_sak*sub_sak['visitors']\
+rate_aml*sub_aml['visitors']

sub_blending.to_csv('submission_rs_recruit_v18_blending_06.csv', index=False)
# xgb
# lgm
# knr
# sakata method
# aml
# blending xgb:2,lgb:2,knr:2,sakata method:2,aml:2
# LB 0.479

# %% [markdown]
# ### 26-Jan-2018 v2

# %%
import pandas as pd
sub_xgb = pd.read_csv('./submission_rs_recruit_v14_xgb_linear_feature_engineering_shinji_02.csv')
sub_lgb = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_shinji_02.csv')
sub_knr = pd.read_csv('./submission_rs_recruit_v16_knr_feature_engineering_shinji_02.csv')

sub_blending = pd.DataFrame()
sub_blending['id'] = sub_xgb['id']

# %%
rate_xgb = 0.3
rate_lgb = 0.4
rate_knr = 0.3

# %%
sub_blending['visitors'] = rate_xgb*sub_xgb['visitors']+rate_lgb*sub_lgb['visitors']+rate_knr*sub_knr['visitors']
sub_blending.to_csv('submission_rs_recruit_v18_blending_05.csv', index=False)
# xgb
# lgm
# knr
# blending xgb:3,lgb:4,knr:3
# LB 0.480

# %% [markdown]
# ### 26-Jan-2018

# %%
import pandas as pd
sub_xgb = pd.read_csv('./submission_rs_recruit_v14_xgb_linear_feature_engineering_shinji_02.csv')
sub_lgb = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_shinji_02.csv')
sub_knr = pd.read_csv('./submission_rs_recruit_v16_knr_feature_engineering_shinji_02.csv')

sub_blending = pd.DataFrame()
sub_blending['id'] = sub_xgb['id']

# %%
rate_xgb = 0.4
rate_lgb = 0.4
rate_knr = 0.2

# %%
sub_blending['visitors'] = rate_xgb*sub_xgb['visitors']+rate_lgb*sub_lgb['visitors']+rate_knr*sub_knr['visitors']
sub_blending.to_csv('submission_rs_recruit_v18_blending_04.csv', index=False)
# xgb
# lgm
# knr
# blending xgb:4,lgb:4,knr:2
# LB 0.480

# %% [markdown]
# ### 25-Jan-2018

# %%
import pandas as pd
sub_xgb = pd.read_csv('./submission_rs_recruit_v14_xgb_linear_feature_engineering_shinji_02.csv')
sub_lgb = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_shinji_02.csv')

sub_blending = pd.DataFrame()
sub_blending['id'] = sub_xgb['id']

# %%
rate_xgb = 0.5
rate_lgb = 0.5

# %%
sub_blending['visitors'] = rate_xgb*sub_xgb['visitors']+rate_lgb*sub_lgb['visitors']
sub_blending.to_csv('submission_rs_recruit_v18_blending_03.csv', index=False)
# xgb
# lgm
# blending xgb:5,lgb:5
# LB 0.480

# %% [markdown]
# ### Test 1

# %%
import pandas as pd

# %%
sub_automl = pd.read_csv('../../../mltestdata/05_recruit/submission_automl.csv')
sub_lgbv15 = pd.read_csv('./submission_rs_recruit_v15_lgbm_feature_engineering_02.csv')
sub_blending = pd.DataFrame()
sub_blending['id'] = sub_automl['id']

# %%
rate_automl = 0.8
rate_lgbboptweight = 0.2

# %%
sub_blending['visitors'] = rate_automl*sub_automl['visitors']+rate_lgbboptweight*sub_lgbboptweight['visitors']
sub_blending.to_csv('submission_rs_recruit_v11_lgbm_v04_03.csv', index=False)
# LB 0.480

# %% [markdown]
# ### Test 2

# %%
sub_automl = pd.read_csv('../../../mltestdata/05_recruit/submission_automl.csv')
sub_stacking = pd.read_csv('./submission_rs_recruit_v17_stacking_01.csv')
sub_blending = pd.DataFrame()
sub_blending['id'] = sub_stacking['id']

# %%
rate_automl = 0.8
rate_stackingweight = 0.2

# %%
sub_blending['visitors'] = rate_automl*sub_automl['visitors']+rate_stackingweight*sub_stacking['visitors']
sub_blending.to_csv('submission_rs_recruit_v18_blending_01.csv', index=False)

# gw_flag
# xgb
# Bopt
# weight
# Stacking (lv1:knr,lgb,xgb, lv2:xgb)
# Blending with automl 8:2
# LB 0.480

# %% [markdown]
# ### Test3

# %%
rate_automl = 0.7
rate_stackingweight = 0.3

# %%
sub_blending['visitors'] = rate_automl*sub_automl['visitors']+rate_stackingweight*sub_stacking['visitors']
sub_blending.to_csv('submission_rs_recruit_v18_blending_02.csv', index=False)

# gw_flag
# xgb
# Bopt
# weight
# Stacking (lv1:knr,lgb,xgb, lv2:xgb)
# Blending with automl 7:3
# LB 0.481
